# %% [markdown]
# # Data loading and visualization
# ## Part 1 of the series of notebooks to solve the competition
#
# In this notebook, data analysis and visualization is performed on training and testing data sets. It is inspired by the available competition notebooks and the discussion form.
#
# ## Content:
#   - [Import required modules](#Import%20required%20modules)
#   - [load data](#load%20data)
#   - [Data analysis](#Data%20analysis)
#   - [Length distrepution befor data cleaning](#distrepution befor data cleaning)
#   - [Word frequency function ](#Word frequency function)
#   - [Data cleaning](#Data cleaning)
#   - [Neutral data analysis](#Neutral data analysis)

# %% [markdown]
# ### Import required modules

# %%
# jupyter majec function to print images inlined
# %matplotlib inline 

import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # ploting.
import seaborn as sns # more cool plotting 
from nltk.corpus import stopwords # load stoping words
from nltk.tokenize import word_tokenize # word tokenizer
import operator

pd.set_option('display.max_colwidth', -1)
pd.options.display.max_rows = 100

import re # Regular expression

# %% [markdown]
# ### load data

# %%
dataPath = 'dataset'

#Training data
train = pd.read_csv(dataPath+'/train.csv')
# Testing data 
test = pd.read_csv(dataPath+'/test.csv')

for col in train.columns:
    train[col] = train[col].astype(str)
for col in test.columns:
    test[col] = test[col].astype(str)

print("Train data of shape",train.shape)
print("Test data of shape",test.shape)
# Out:
# Train data of shape (27486, 4)
# Test data of shape (3535, 3)

# %%
# train data sample
elements_from_head=100 # number of elements to show from head

print("Train data first", elements_from_head, "samples")
train.head(elements_from_head)
# Out:
# Train data first 100 samples
#         textID  \
# 0   a3d0a7d5ad
# 1   251b6a6766
# 2   c9e8d1ef1c
# 3   f14f087215
# 4   bf7473b12d
# 5   1915bebcb3
# 6   2ab82634d5
# 7   a5a1c996c0
# 8   a182b2638e
# 9   1dcb6fdb13
# 10  6bff31375d
# 11  e1ed43bebe
# 12  41fd07f670
# 13  bc0f2cb758
# 14  0e6fb9153c
# 15  49c7c9c6e2
# 16  e6f5e9817d
# 17  fee2d997a9
# 18  459fc2a7c8
# 19  1a760553fc
# 20  1e857fecf5
# 21  22adf200c3
# 22  bae5414377
# 23  22744e80f7
# 24  e487233140
# 25  22e66a73af
# 26  01cfa3807e
# 27  7f59b000cd
# 28  127b2ac78c
# 29  a6c77ff610
# 30  436b24fc93
# 31  c63298701b
# 32  4ce78f6e92
# 33  2838f92a2b
# 34  9dd2edd0fd
# 35  d86eaa0487
# 36  2756df3899
# 37  daadcab8af
# 38  2334cae701
# 39  89fc963188
# 40  ebe46589f3
# 41  7f0c862bad
# 42  b63f6f0bf9
# 43  118850b843
# 44  2d5648ba3c
# 45  ad6c3de0ae
# 46  791449f114
# 47  4f26fc0981
# 48  95c725edb6
# 49  fe98872319
# 50  5498496af0
# 51  d11234ed68
# 52  e6dedf3aad
# 53  556f187ce7
# 54  0bc6d79c40
# 55  384c73b996
# 56  e41986b2d9
# 57  3440297f8b
# 58  f09c712326
# 59  acdea0cf39
# 60  675bb05b9d
# 61  97bc17f4b4
# 62  0338930089
# 63  07836035cd
# 64  dfc5afdab4
# 65  b5167d5a96
# 66  060d8bb5d5
# 67  3d37d0aa09
# 68  021e4d7fd7
# 69  4ffb09c454
# 70  f29df52d91
# 71  196107983d
# 72  2f2542a3c2
# 73  134b4e3267
# 74  Is the Bee to Busy to talk to his buddy on Yahoo?
# 75  I need followers!!!
# 76  Im on my way to brookings
# 77  _44 Thanks!! It was a bit out of my comfort zone but it was fun
# 78  stress
# 79  is watching the canucks
# 80  good person
# 81  blerg, **** you Monday, why must you always come.  Decent weekend, new glasses, hair color and got carded at Gamestop = awesome ego boost
# 82  hoping
# 83  gprof problem on Mac  why ??
# 84  e nice
# 85  ! How exciting!
# 86  done with the fkn exam! n just bought the mothers day gift, finally... tada! the new prada fragrance  going to meet up mum n fam now : ...
# 87  had a good time.
# 88  Goodnight Beautiful world  sweet dreams. olive juice!
# 89  love
# 90  Yay for St Louis traffic
# 91  I have to pee.
# 92  hhahaa!    its well strange just woke up to an empty house ahah  lolllllyyyyyyyy&lt;3 love th
# 93  awesome!
# 94  i got followed by one that says she doesn't talk to &quot;god people&quot;-i wonder if she talks to &quot;god
# 95  uh wait...i thought this was the 29th...tonight
# 96  doesn't like
# 97  Great meeting..
# 98  &quot;We did it we did it oh yea yea yea no eating here tonite woo eating here tonight no no no eating here tonite you on a diet&quot; findi
# 99  hey adt, guess what. my princelple's number plate is adtï¿½000 well its not 000, i just dunno the numbers.
#
#    sentiment
# 0   neutral
# 1   positive
# 2   neutral
# 3   negative
# 4   positive
# 5   negative
# 6   positive
# 7   positive
# 8   positive
# 9   neutral
# 10  neutral
# 11  neutral
# 12  negative
# 13  positive
# 14  neutral
# 15  negative
# 16  negative
# 17  negative
# 18  negative
# 19  neutral
# 20  neutral
# 21  negative
# 22  negative
# 23  positive
# 24  positive
# 25  neutral
# 26  positive
# 27  neutral
# 28  neutral
# 29  positive
# 30  neutral
# 31  neutral
# 32  positive
# 33  neutral
# 34  positive
# 35  negative
# 36  negative
# 37  positive
# 38  negative
# 39  neutral
# 40  positive
# 41  positive
# 42  neutral
# 43  negative
# 44  neutral
# 45  negative
# 46  neutral
# 47  positive
# 48  negative
# 49  positive
# 50  neutral
# 51  positive
# 52  negative
# 53  neutral
# 54  positive
# 55  neutral
# 56  negative
# 57  negative
# 58  negative
# 59  negative
# 60  negative
# 61  neutral
# 62  positive
# 63  negative
# 64  neutral
# 65  negative
# 66  negative
# 67  positive
# 68  neutral
# 69  positive
# 70  neutral
# 71  neutral
# 72  neutral
# 73  negative
# 74  neutral
# 75  neutral
# 76  neutral
# 77  neutral
# 78  negative
# 79  neutral
# 80  positive
# 81  neutral
# 82  positive
# 83  neutral
# 84  positive
# 85  positive
# 86  neutral
# 87  positive
# 88  positive
# 89  positive
# 90  neutral
# 91  neutral
# 92  neutral
# 93  positive
# 94  neutral
# 95  neutral
# 96  negative
# 97  positive
# 98  neutral
# 99  neutral

# %%
# train data sample
elements_random=100 # number of random elements to show

print("Train data random", elements_random, "samples")
train.sample(elements_random)
# Out:
# Train data random 100 samples
#            textID  \
# 1980   7e1ee83e72
# 11401  63ea89fdc7
# 15940  552f2be123
# 17588  1abc302eb4
# 20612  be0a927a80
# 9155   d8788056b3
# 24219  8fe788817b
# 18181  e9f7f78cfa
# 13318  221b3132af
# 27051  Ed is awake! But Andy doesn't feel so hot so she's still sleeping.
# 4905   Ah now Comedy Central have Frasier all morning till twelve. So I guess there goes my morning
# 24004  the justice left when DJ Talent was voted off (N)
# 18763  squirted
# 18827  off to my Psychology class.
# 194    great
# 17836  excited
# 20238  a lovely
# 5129   no, dayuuum 5o'clock was better
# 1761   looking forward to the show tonight. Can't wait for ol mate  to
# 21077  awessomee!
# 14583  LOVED
# 22771  worse,
# 1935   put ad on craigslist/Quebec 4 tan salad plates with bird drawings  can only do 1 area @ time. I still need 3 more. Got 2 at my Tuesday AM
# 5041   thnkn bout yesterday..best day ever!&amp; 2day Virtus vs Treviso at da futurshow..hard game,gotta win! FORZA RAGAZZI!
# 9625   Thanks! We're still all passing around germs here but we're surviving.  Have I missed anything?
# 12698  thanx
# 16830  My roommate has officially started packing
# 3026   yummy
# 4964   it was gone
# 22813  sorry,
# 5688   sorry but so happy
# 832    great
# 849    yeah I'm fine not to raid most things. Excepting liquor and cheese &amp; bacon ba
# 26413  Haha most def ^__^ Rob a bank with me so i could get all the swedish fishes in the world
# 26285  getting ready to shop  birmingham here i come
# 16218  yummy.
# 9092   is slowly gettin more followers  vry slowly
# 17227  shweeeeet!
# 11365  if you need to talk or vent let me know
# 21997  pretty burnt
# 10996  keep dreamin'!!!! Though.... if she does.... hook me up  LOL
# 8428   Angus down 3-1 in first set     http://yfrog.com/10jsep
# 14700  More to thank for #ff shouts     and heaps more. Sry will be here all night i now realis
#
#       sentiment
# 1980   neutral
# 11401  positive
# 15940  neutral
# 17588  negative
# 20612  neutral
# 9155   neutral
# 24219  negative
# 18181  positive
# 13318  neutral
# 2740   positive
# 26684  neutral
# 1284   neutral
# 7779   positive
# 13888  neutral
# 18192  neutral
# 1601   neutral
# 1184   positive
# 23654  neutral
# 5374   neutral
# 1455   positive
# 2550   positive
# 20396  negative
# 24836  positive
# 18020  positive
# 444    positive
# 20386  positive
# 16236  negative
# 8740   positive
# 4624   positive
# 18169  negative
# 7564   positive
# 26528  neutral
# 2458   neutral
# 14010  positive
# 25230  negative
# 21776  neutral
# 14661  positive
# 23856  positive
# 18918  neutral
# 18676  negative
# 17028  neutral
# 251    neutral
# 16951  neutral
# 4115   positive
# 23538  positive
# 207    negative
# 1237   positive
# 16617  negative
# 5422   neutral
# 7377   neutral
# 16850  negative
# 12362  neutral
# 3832   positive
# 16657  positive
# 17421  positive
# 20507  positive
# 8994   positive
# 8663   negative
# 3985   positive
# 877    neutral
# 8810   positive
# 26651  negative
# 12226  neutral
# 15518  neutral
# 26671  neutral
# 23046  neutral
# 27051  neutral
# 4905   neutral
# 24004  neutral
# 18763  negative
# 18827  neutral
# 194    positive
# 17836  positive
# 20238  positive
# 5129   neutral
# 1761   neutral
# 21077  positive
# 14583  positive
# 22771  negative
# 1935   neutral
# 5041   neutral
# 9625   neutral
# 12698  positive
# 16830  neutral
# 3026   positive
# 4964   negative
# 22813  negative
# 5688   neutral
# 832    positive
# 849    neutral
# 26413  neutral
# 26285  neutral
# 16218  positive
# 9092   neutral
# 17227  positive
# 11365  neutral
# 21997  negative
# 10996  neutral
# 8428   neutral
# 14700  neutral

# %%
# test data sample

print("Test data first", elements_from_head, "samples")
test.head(elements_from_head)
# Out:
# Test data first 100 samples
#         textID  \
# 0   11aa4945ff
# 1   fd1db57dc0
# 2   2524332d66
# 3   0fb19285b2
# 4   e6c9e5e3ab
# 5   311d2b185b
# 6   95dfefd4e7
# 7   739f17cfe1
# 8   c6322a85c2
# 9   b4401d6b4d
# 10  934ac753a2
# 11  3f8fc09752
# 12  a8e2c45625
# 13  d761530c7f
# 14  bb8443d7e2
# 15  41c5bce464
# 16  d5c25dbc63
# 17  7a897c9999
# 18  4d7def819d
# 19  a8e17db0cc
# 20  bbf1006316
# 21  0fe8023456
# 22  949020a350
# 23  f90a6f5da0
# 24  390f169584
# 25  0de656eac1
# 26  144e6fb3ad
# 27  9a55d83c79
# 28  27829d97bd
# 29  bebfd966a0
# 30  4626b8b37a
# 31  bf9189459f
# 32  4cc3d3824c
# 33  70187852a7
# 34  094681e31c
# 35  16357f7283
# 36  5aa568e0a4
# 37  003816f151
# 38  df1baec676
# 39  9f23e5d8f5
# 40  316d5aeaf6
# 41  ca10e6b390
# 42  f97b6d38ed
# 43  42e4df338b
# 44  cee062574a
# 45  d3935b8571
# 46  409767144d
# 47  a203734990
# 48  a267c3e874
# 49  389fc0d397
# 50  c3feee17fd
# 51  1620bd719e
# 52  f321d7a256
# 53  9e5e8ab6a4
# 54  6cadda7b98
# 55  b84ea78203
# 56  0b6444627a
# 57  c780b84d97
# 58  3ab338c459
# 59  db7211afbf
# 60  f8456f260f
# 61  5773cb0640
# 62  8837fac289
# 63  37681f23e9
# 64  7a09871d21
# 65  9eb21f1e58
# 66  fa625455c7
# 67  5dbb7ae2a3
# 68  16ca8a5ecc
# 69  4f8c391159
# 70  16ac3c903c
# 71  87c799a397
# 72  80995dff29
# 73  342c394b9e
# 74  1eabe43846
# 75  e8ce4f8bdc
# 76  52aad0e22e
# 77  3d0c74e523
# 78  2492330594
# 79  7e19629684
# 80  5a17107aba
# 81  fc6128f4e5
# 82  2a054d9205
# 83  2f9f6f89cd
# 84  4ea7102112
# 85  bd8ba2ad7e
# 86  23602f214f
# 87  f7ac9e16e5
# 88  c8a9799256
# 89  8fd01857a9
# 90  b56108fc36
# 91  85859d775f
# 92  172b9d5155
# 93  540fd43bae
# 94  a9b6058320
# 95  5428d6a1dd
# 96  390f00c85a
# 97  75b30e5358
# 98  fa959f2dd3
# 99  00276ae6b1
#
#                                                                                                                                   text  \
# 0    http://twitpic.com/67swx - i wish i was calling you but i can't from Malta
# 1   i'm done.haha. HOUSE MD marathon ulet
# 2    I'm concerned for that family
# 3   HEY GUYS IT'S WORKING NO NEED TO WORRY. i have tooo many followers tho ...
# 4    26th February
# 5   Tracy and Berwick breaks my achy breaky heart  They split ways in the hallways.
# 6   Well off 2 bed...cant wait 2 party 4 Mother's Day in like 14 hours or so
# 7   Oh yeah the camera clipping problems with Void are now completely fixed  yay me for fiddling about
# 8   _Layne  hmm.. what's ur fav movie?? tv shows??
# 47  positive
# 48  neutral
# 49  neutral
# 50  positive
# 51  neutral
# 52  positive
# 53  negative
# 54  positive
# 55  positive
# 56  neutral
# 57  neutral
# 58  positive
# 59  negative
# 60  neutral
# 61  positive
# 62  positive
# 63  neutral
# 64  neutral
# 65  negative
# 66  negative
# 67  neutral
# 68  neutral
# 69  neutral
# 70  neutral
# 71  negative
# 72  neutral
# 73  positive
# 74  negative
# 75  neutral
# 76  positive
# 77  negative
# 78  neutral
# 79  neutral
# 80  negative
# 81  neutral
# 82  neutral
# 83  neutral
# 84  positive
# 85  positive
# 86  negative
# 87  positive
# 88  neutral
# 89  neutral
# 90  positive
# 91  neutral
# 92  negative
# 93  positive
# 94  neutral
# 95  negative
# 96  negative
# 97  neutral
# 98  negative
# 99  neutral

# %%
print("Test data random", elements_random, "samples")
test.sample(elements_random)
# Out:
# Test data random 100 samples
#           textID  \
# 1692  5cc015ed85
# 1436  01f2c9bae6
# 1278  a4ab64c15c
# 1054  59ee5ff2f9
# 2018  80b171ef7a
# 73    342c394b9e
# 2456  83b44dda65
# 1720  c467f58715
# 3228  1e32ad1b17
# 1994  93eb6effbb
# 1635  9d4dfb1f9e
# 1258  e9c8585ad1
# 1375  1c66900f85
# 3008  d65a8658b0
# 2613  51313cb3fd
# 381   e89cbe91e0
# 1334  855545a974
# 3416  3b743ded7e
# 644   241afcd4ec
# 569   2c39030bc4
# 1722  f837a046a9
# 2454  0c35e093bd
# 3087  5d9e44e6aa
# 334   f877442216
# 1862  2c4b87059b
# 2279  e83b4e9bf0
# 2651  e01eb1cf88
# 1834  f6f7382036
# 265   3285374ab0
# 992   7b474b659d
# 1271  86c20cf6ee
# 2411  932af12853
# 338   0e5d9cd378
# 2518  2bca22c7f3
# 284   e131c496a2
# 1925  62aebe35b6
# 131   6940969fb4
# 2015  cfdb8ea6d8
# 1554  b01100d6c6
# 2248  fd1ebb37c3
# 581   970d89d516
# 2776  6c409292ce
# 476   065e4c2dba
# 2014  5f91766356
# 257   d4623c0bd6
# 1094  6913d9c30e
# 513   3af70d3bc2
# 1419  d6dcf8c5ef
# 1668  3f6bf57365
# 2134  7223fdccc2
# 1799  eeb047e369
# 266   653f3adcde
# 1665  5f4e052208
# 3278  65019c18cb
# 233   320a6e56fc
# 825   4f05a05989
# 2677  e78f6d920b
# 1642  4a13c1093d
# 297   1fb1670192
# 2867  451880b8a6
# 2617  bf4c610e53
# 2536  43b390b336
# 3140  b8f7efe383
# 2594  ee9eaed59b
# 1502  e887fbdfd5
# 771   68bf3f1fec
# 3218  cc75fbff94
# 198   4d818fe6e0
# 1501  7bbc5a2473
# 1971  db783cf66a
# 2118  37daa255ea
# 2479  b01506af48
# 1255  894e948ead
# 2762  74e71ffd48
# 3251  b1caa80c14
# 1048  3e99500fa4
# 1402  121b9c13c2
# 121   7fb2ca19e9
# 2658  c5f383c0a0
# 1118  7db53ed89f
# 3184  4e38efebc2
# 910   2cebd75ed4
# 45    d3935b8571
# 953   00ce730001
# 3489  13fccb0fb5
# 1198  02883c7ab1
# 2716   Thank you so much phaoloo !!!!
# 1882   (RE:&quot;your joint w/  is crazy!!&quot;) Thx    Hey Trax heard a 49er rear ended you??
# 3503  Going to tmobile  i need a new phone this G1 is so not working for me anymore
# 1329   Thanks for adding me
# 2999   my baby shut me down
# 1027  10.11PM~ todays a drag for me. so bored. im about to get into the romance book so i prob wont be on til the morn  night twitter babes ;)
# 2984    sadly we were too late for TraceyCakes, but we got them elsewhere- not the same but still yummy. Tea w wee on wknd!
# 1787   i always have those for my Champions League parties  Tis awesome
# 2644   its definitely coming, hope ur ready!
#
#      sentiment
# 1692  neutral
# 1436  neutral
# 1278  positive
# 1054  negative
# 2018  negative
# 73    positive
# 2456  positive
# 1720  negative
# 3228  positive
# 1994  positive
# 1635  neutral
# 1258  neutral
# 1375  neutral
# 3008  positive
# 2613  neutral
# 381   neutral
# 1334  positive
# 3416  positive
# 644   positive
# 569   positive
# 1722  positive
# 2454  positive
# 3087  neutral
# 334   negative
# 1862  neutral
# 2279  negative
# 2651  positive
# 1834  negative
# 265   negative
# 992   neutral
# 1271  positive
# 2411  positive
# 338   negative
# 2518  neutral
# 284   neutral
# 1925  neutral
# 131   negative
# 2015  neutral
# 1554  neutral
# 2248  neutral
# 581   neutral
# 2776  neutral
# 476   negative
# 2014  neutral
# 257   positive
# 1094  neutral
# 513   neutral
# 1419  negative
# 1668  neutral
# 2134  positive
# 1799  neutral
# 266   positive
# 1665  neutral
# 3278  positive
# 233   negative
# 825   positive
# 2677  neutral
# 1642  neutral
# 297   negative
# 2867  positive
# 2617  positive
# 2536  neutral
# 3140  neutral
# 2594  neutral
# 1502  negative
# 771   negative
# 3218  neutral
# 198   neutral
# 1501  positive
# 1971  positive
# 2118  positive
# 2479  neutral
# 1255  positive
# 2762  neutral
# 3251  positive
# 1048  negative
# 1402  positive
# 121   neutral
# 2658  negative
# 1118  positive
# 3184  negative
# 910   neutral
# 45    neutral
# 953   negative
# 3489  negative
# 1198  neutral
# 3175  positive
# 1914  neutral
# 3227  neutral
# 562   negative
# 839   negative
# 2716  positive
# 1882  positive
# 3503  negative
# 1329  positive
# 2999  negative
# 1027  negative
# 2984  neutral
# 1787  positive
# 2644  positive

# %% [markdown]
# ### Data analysis

# %%
pos,neg,nat=train['sentiment'].value_counts()


print("Training data")
print("Number of positive is {}, number of negative is {}, and number of neutral is {}".format(pos,neg,nat))
sns.countplot(x='sentiment',data=train)
print("Train Data Sentiment")
# Out:
# Training data
# Number of positive is 11118, number of negative is 8582, and number of neutral is 7786
# Train Data Sentiment

# %%
pos2,neg2,nat2=test['sentiment'].value_counts()


print("Testing data")
print("Number of positive is {}, number of negative is {}, and number of neutral is {}".format(pos2,neg2,nat2))
sns.countplot(x='sentiment',data=train)
print("Test Data Sentiment")
# Out:
# Testing data
# Number of positive is 1430, number of negative is 1104, and number of neutral is 1001
# Test Data Sentiment

# %%
sentament = ["neutral","positive","negative"]
diff=[nat/train.shape[0]-nat2/test.shape[0], pos/train.shape[0]-pos2/test.shape[0], neg/train.shape[0]-neg2/test.shape[0]]

print("Train - Test")
print("Number of positive is {}, number of negative is {}, and number of neutral is {}".format(diff[1],diff[2],diff[0]))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(sentament,diff)
plt.show()
# Out:
# Train - Test
# Number of positive is -2.9332150166982984e-05, number of negative is -7.383468256078052e-05, and number of neutral is 0.00010316683272781901

# %% [markdown]
# ### Length distrepution befor data cleaning

# %%
#for train text

lens = [len(x) for x in train.text]
plt.figure(figsize=(12, 5));
print ("max: {}, min: {}, mean: {:.5}".format(max(lens), min(lens), np.mean(lens)))
sns.distplot(lens);
plt.title('Train text length distribution')
# Out:
# max: 165, min: 3, mean: 68.725
# Text(0.5, 1.0, 'Train text length distribution')

# %%
# for train selected_text

lens = [len(x) for x in train.selected_text]
plt.figure(figsize=(12, 5));
print ("max: {}, min: {}, mean: {:.5}".format(max(lens), min(lens), np.mean(lens)))
sns.distplot(lens);
plt.title('Train selected_text length distribution')
# Out:
# max: 141, min: 1, mean: 36.747
# Text(0.5, 1.0, 'Train selected_text length distribution')

# %%
#for test text

lens = [len(x) for x in test.text]
plt.figure(figsize=(12, 5));
print ("max: {}, min: {}, mean: {:.5}".format(max(lens), min(lens), np.mean(lens)))
sns.distplot(lens);
plt.title('Test text length distribution')
# Out:
# max: 155, min: 4, mean: 68.188
# Text(0.5, 1.0, 'Test text length distribution')

# %% [markdown]
# ### Word frequency function

# %%
def word_frequency(data,return_word_frequency):
    for word in data.split():
        if return_word_frequency.get(word, False): return_word_frequency[word]+=1
        else: return_word_frequency[word]=1
    return return_word_frequency

# %% [markdown]
# ### Data cleaning

# %%
def get_char_only(text):
    chars = re.compile(r"[^a-zA-Z]")
    return chars.sub(r' ',text)

def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

def remove_html(text):
    html=re.compile(r'<.*?>')
    text=html.sub(r'',text)
    return text
    
def remove_stoping_words(text):
    stop=set(stopwords.words('english'))
    return " ".join([x for x in word_tokenize(text) if x not in stop])

# def remove_stoping_words(data):
#     return [ remove_stopwords_statment(i) for i in data]

def remove_emoji(text): 
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def remove_tag(text):
    return ' '.join(re.sub("[@][\w_-]+"," ",text).split())


def clean_data(data): # data must by list only
    data= data.apply(lambda x : remove_html(x))
    data= data.apply(lambda x : remove_URL(x))
    data= data.apply(lambda x : remove_emoji(x))
    data= data.apply(lambda x : remove_tag(x))
    data= data.apply(lambda x : get_char_only(x))
    data= data.apply(lambda x : remove_stoping_words(x))    
    return data

def clean_train():
    train_df=train.copy()
    train_df.text=clean_data(data=train.text)
    train_df.selected_text=clean_data(train.selected_text)
    return train_df
    
def clean_test():
    test.text=clean_data(test.text)

# %%
train_df = clean_train()
train_df.head(100)
# Out:
#         textID  \
# 0   a3d0a7d5ad
# 1   251b6a6766
# 2   c9e8d1ef1c
# 3   f14f087215
# 4   bf7473b12d
# 5   1915bebcb3
# 6   2ab82634d5
# 7   a5a1c996c0
# 8   a182b2638e
# 9   1dcb6fdb13
# 10  6bff31375d
# 11  e1ed43bebe
# 12  41fd07f670
# 13  bc0f2cb758
# 14  0e6fb9153c
# 15  49c7c9c6e2
# 16  e6f5e9817d
# 17  fee2d997a9
# 18  459fc2a7c8
# 19  1a760553fc
# 20  1e857fecf5
# 21  22adf200c3
# 22  bae5414377
# 23  22744e80f7
# 24  e487233140
# 25  22e66a73af
# 26  01cfa3807e
# 27  7f59b000cd
# 28  127b2ac78c
# 29  a6c77ff610
# 30  436b24fc93
# 31  c63298701b
# 32  4ce78f6e92
# 33  2838f92a2b
# 34  9dd2edd0fd
# 35  d86eaa0487
# 36  2756df3899
# 37  daadcab8af
# 38  2334cae701
# 39  89fc963188
# 40  ebe46589f3
# 41  7f0c862bad
# 42  b63f6f0bf9
# 43  118850b843
# 44  2d5648ba3c
# 45  ad6c3de0ae
# 46  791449f114
# 47  4f26fc0981
# 48  95c725edb6
# 49  fe98872319
# 50  5498496af0
# 51  d11234ed68
# 52  e6dedf3aad
# 53  556f187ce7
# 54  0bc6d79c40
# 55  384c73b996
# 56  e41986b2d9
# 57  3440297f8b
# 58  f09c712326
# 59  acdea0cf39
# 60  675bb05b9d
# 61  97bc17f4b4
# 62  0338930089
# 63  07836035cd
# 64  dfc5afdab4
# 65  b5167d5a96
# 66  060d8bb5d5
# 67  3d37d0aa09
# 68  021e4d7fd7
# 69  4ffb09c454
# 70  f29df52d91
# 71  196107983d
# 72  2f2542a3c2
# 73  134b4e3267
# 74  5ac1a82457
# 75  aaee08f683
# 76  ba5468c0c3
# 77  269e7185cb
# 78  193909d380
# 79  ba8aa5e888
# 80  b4d9e63784
# 81  dfeadc340d
# 82  f4f97d8289
# 83  b2fed31eb7
# 84  6903cb08f2
# 85  7a0f49dddd
# 86  b2986c944a
# 87  653cf8e5a6
# 88  514174445d
# 89  88c05add09
# 90  eaa0b85855
# 91  ab56747ae1
# 92  b57188597f
# 93  7e4579c8f9
# 94  f20fecf55e
# 95  f6ca88db6f
# 96  067058825c
# 97  b084bce92a
# 98  2ef8bef8cf
# 99  aa4412f02c
#
#                                                                                                            text  \
# 0   Spent entire morning meeting w vendor boss happy w Lots fun I plans morning
# 1   Oh Good idea putting ice cream
# 2   says good say bad afternoon
# 3   dont think vote anymore tried
# 4   haha better drunken tweeting mean
# 5   headache wan na see Julie
# 6   awsome salad I recommend getting Spicey buffalo chicken salad
# 7   fine Going big walk today miles
# 8   Thank yoou TwitterTakeover
# 9   Why adobe realise one WANTS pay Photoshop et al give us free
# 10  PRD take long time review
# 11  Well revise Was gardening I guess hoovering warcraft Not played week
# 12  Miss dear
# 13  Have bought TV tuner laptop He I deserve present
# 14  ya mine different reason
# 15  Today Dan bought Bio Dome AND Reality Bites Soundtrack Needless say gets MAYJAH points Also tummy happy Boo
# 16  oo noo thats good
# 17  misses phone service sucks
# 18  like friends kinda sad
# 19  perused fieldnotes website good bad must return work
# 20  welcome public transport X
# 21  Also I popped phone open got goddamn dust I wore clip camera panel I glue shut
# 22  uh oh
# 23  AM HAppy birthday little sister mine Also good night Priscilla
# 24  aaawww worries fresh start work growing
# 25  oh still got around starting
# 26  sooo tired busy tweet im glad weekend yay day weekend
# 27  going
# 28  I I studying I fail Come I make u tortellini chicken chicken salad
# 29  Just watched quot Marley amp Me quot Cute movie Going watch quot Twilight quot soon Love
# 30  sure fanciful expensive ones basic ones expensive Try hr M shopping place
# 31  hello thereeeeeee
# 32  oh cute uniteddogs com Poppy
# 33  joined twitter community
# 34  actually starting quite like lily allen music honest
# 35  Brody dare u
# 36  I feel useless I know right I bored
# 37  I sooo HAPPY Demi back twitter
# 38  kate leaving lonesome
# 39  I rooting Betty
# 40  That would welcome
# 41  Why weddings TV make cry Is inner desire eternally happy start rest life
# 42  Is hungry sub
# 43  I lost follower oh well probably one mute ones anyway
# 44  see
# 45  saying goodbye something familiar never becomes familiar
# 46  I comment directly someone I alone
# 27  going
# 28  I I studying I fail Come I make u tortellini chicken chicken salad
# 29  mp Me
# 30  sure fanciful expensive ones basic ones expensive
# 31  hello thereeeeeee
# 32  cute
# 33  joined twitter community
# 34  quite like lily allen music honest
# 35  Brody dare u
# 36  useless
# 37  I sooo HAPPY De
# 38  lonesome
# 39  I rooting Betty
# 40  That would welcome
# 41  happy
# 42  Is hungry sub
# 43  lost
# 44  see
# 45  never becomes familiar
# 46  I comment directly someone I alone
# 47  aw cute
# 48  I absolutely exhausted
# 49  So good Glad finally got see
# 50  years trying cat today figured open sink cupboard time target run buy safety locks
# 51  Have great day everyone
# 52  dog ran awayyy
# 53  omggg quot crazy cobras quot wantewd see
# 54  Today seems like good day
# 55  It Raining
# 56  missing someone
# 57  sigh
# 58  Hot
# 59  ouch
# 60  scary
# 61  waiting mom get home
# 62  love
# 63  damm
# 64  UGH I soooo drag assing today brighter note I got G update amp biznesss
# 65  Feels like im going cough lung
# 66  I miss
# 67  nice
# 68  See may
# 69  hall gutted lmao think obsessed bahaha
# 70  I want know auditions Mander Text reply please
# 71  I stop bit I But rush rehearsal quiet tonight
# 72  Whoa I mean sleep hour
# 73  In bed good last saturday ec I gon na miss place wait til summer
# 74  Is Bee Busy talk buddy Yahoo
# 75  I need followers
# 76  Im way brookings
# 77  Thanks It bit comfort zone fun
# 78  stress
# 79  watching canucks
# 80  good person
# 81  blerg Monday must always come Decent weekend new glasses hair color got carded Gamestop awesome ego boost
# 82  hoping
# 83  gprof problem Mac
# 84  e nice
# 85  How exciting
# 86  done fkn exam n bought mothers day gift finally tada new prada fragrance going meet mum n fam
# 87  good time
# 88  Goodnight Beautiful world sweet dreams olive juice
# 89  love
# 90  Yay St Louis traffic
# 91  I pee
# 92  hhahaa well strange woke empty house ahah lolllllyyyyyyyy lt love th
# 93  awesome
# 94  got followed one says talk quot god people quot wonder talks quot god
# 95  uh wait thought th tonight
# 96  like
# 97  Great meeting
# 98  quot We oh yea yea yea eating tonite woo eating tonight eating tonite diet quot findi
# 99  hey adt guess princelple number plate adt well dunno numbers
#
#    sentiment
# 0   neutral
# 1   positive
# 2   neutral
# 3   negative
# 4   positive
# 5   negative
# 6   positive
# 7   positive
# 8   positive
# 9   neutral
# 10  neutral
# 11  neutral
# 12  negative
# 13  positive
# 14  neutral
# 15  negative
# 16  negative
# 17  negative
# 18  negative
# 19  neutral
# 20  neutral
# 21  negative
# 22  negative
# 23  positive
# 24  positive
# 25  neutral
# 26  positive
# 27  neutral
# 28  neutral
# 29  positive
# 30  neutral
# 31  neutral
# 32  positive
# 33  neutral
# 34  positive
# 35  negative
# 36  negative
# 37  positive
# 38  negative
# 39  neutral
# 40  positive
# 41  positive
# 42  neutral
# 43  negative
# 44  neutral
# 45  negative
# 46  neutral
# 47  positive
# 48  negative
# 49  positive
# 50  neutral
# 51  positive
# 52  negative
# 53  neutral
# 54  positive
# 55  neutral
# 56  negative
# 57  negative
# 58  negative
# 59  negative
# 60  negative
# 61  neutral
# 62  positive
# 63  negative
# 64  neutral
# 65  negative
# 66  negative
# 67  positive
# 68  neutral
# 69  positive
# 70  neutral
# 71  neutral
# 72  neutral
# 73  negative
# 74  neutral
# 75  neutral
# 76  neutral
# 77  neutral
# 78  negative
# 79  neutral
# 80  positive
# 81  neutral
# 82  positive
# 83  neutral
# 84  positive
# 85  positive
# 86  neutral
# 87  positive
# 88  positive
# 89  positive
# 90  neutral
# 91  neutral
# 92  neutral
# 93  positive
# 94  neutral
# 95  neutral
# 96  negative
# 97  positive
# 98  neutral
# 99  neutral

# %%
train_text_freq={}
for i in train_df.text:
    train_count_freq = word_frequency(i,train_text_freq)
    
# train_text_freq = train_df.text.apply(lambda x : word_frequency(x,train_text_freq) )

sorted_train_text_freq = sorted(train_text_freq.items(), key=operator.itemgetter(1))
print(sorted_train_text_freq[-11:-1])
# Out:
# [('going', 951), ('today', 1061), ('work', 1097), ('got', 1097), ('go', 1215), ('good', 1273), ('quot', 1292), ('like', 1305), ('get', 1388), ('day', 1679)]

# %%
train_selected_text_freq={}
for i in train_df.selected_text:
    train_selected_text_freq = word_frequency(i,train_selected_text_freq)
    
# train_text_freq = train_df.text.apply(lambda x : word_frequency(x,train_text_freq) )

sorted_train_selected_text_freq = sorted(train_selected_text_freq.items(), key=operator.itemgetter(1))
print(sorted_train_selected_text_freq[-11:-1])
# Out:
# [('today', 536), ('got', 569), ('work', 593), ('quot', 607), ('go', 660), ('like', 746), ('love', 749), ('get', 750), ('day', 877), ('good', 1011)]

# %% [markdown]
# ### Neutral data analysis

# %%
neutral = train.loc[train.sentiment == "neutral"]
neutral.head(5)
# Out:
#         textID  \
# 0   a3d0a7d5ad
# 2   c9e8d1ef1c
# 9   1dcb6fdb13
# 10  6bff31375d
# 11  e1ed43bebe
#
#                                                                                                                                     text  \
# 0   Spent the entire morning in a meeting w/ a vendor, and my boss was not happy w/ them. Lots of fun.  I had other plans for my morning
# 2   says good (or should i say bad?) afternoon!  http://plurk.com/p/wxpdj
# 9   Why don't adobe realise no one WANTS to pay for Photoshop et al so they should just give it to us for free
# 10  PRD take a long time to review!
# 11  _2008 Well, having to revise them!  Was to do some more gardening, now, I guess hoovering and some warcraft  Not played in a week !
#
#                                                                                                                        selected_text  \
# 0   my boss was not happy w/ them. Lots of fun.
# 2   says good (or should i say bad?) afternoon!
# 9   Why don't adobe realise no one WANTS to pay for Photoshop et al so they should just give it to us for free
# 10  PRD take a long time to review!
# 11  2008 Well, having to revise them!  Was to do some more gardening, now, I guess hoovering and some warcraft  Not played in a week
#
#    sentiment
# 0   neutral
# 2   neutral
# 9   neutral
# 10  neutral
# 11  neutral

# %%
neutralMisMatch=0
for i in neutral.index:
    if not(neutral.selected_text[i] == neutral.text[i]):
        neutralMisMatch+=1
        
print("neutral mis match between text and selected_text is: ",neutralMisMatch)
print("neutral MATCH between text and selected_text is: ",len(neutral)-neutralMisMatch)
print("neutral % of match: ",((len(neutral)-neutralMisMatch))*100/len(neutral),"%")
# Out:
# neutral mis match between text and selected_text is:  5490
# neutral MATCH between text and selected_text is:  5628
# neutral % of match:  50.62061521856449 %
